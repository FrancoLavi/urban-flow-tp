# %% [markdown]
# # Trabajo Práctico 2 - Urban Flow
#
# Notebook base para el Sprint 2.

# %% [markdown]
# ## Ejercicio 1
#
# Inicialización y configuración de la herramienta de versionado.
